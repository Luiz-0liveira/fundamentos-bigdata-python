# %% [markdown]
# ##### Exercício 02- Manipulando dados com Pandas
#
# arquivo: Venda.xlsx
#
# A) Crie um programa em pandas para ler o arquivo em Exel imobiliária.xlsx

# %%
import pandas as pd

caminho ='C:\\Users\\FIC\\Documents\\Luiz Antonio Python\\003 - Arquivos\\'

arquivo = 'Imobiliária.xlsx'

df = pd.read_excel(caminho + arquivo, sheet_name= 'Base')

# %% [markdown]
# C) Visualizar o cabeçalho dos dados;

# %%
df.head()
# Out:
#    Coluna 1  Coluna 2   Coluna 3     Coluna 4  Coluna 5  Coluna 6  Coluna 7  \
# 0    Centro    Simone 2005-10-08  Apartamento     102.5         2         2
# 1  Noroeste    Simone 2005-10-08  Apartamento     199.5         4         4
# 2     Norte   Roberto 2005-10-12         Casa     145.5         2         2
# 3   Sudeste    Simone 2005-10-14  Apartamento     153.5         3         2
# 4  Noroeste  Cristina 2005-10-16  Apartamento      93.0         2         2
#
#   Coluna 8  Coluna 8.1  Coluna 10
# 0      Sim      235500     3532.5
# 1      Não      377700     5665.5
# 2      Não      232500     3487.5
# 3      Não      289100     4336.5
# 4      Sim      235400     3531.0

# %% [markdown]
# D) Visualizar as últimas linhas

# %%
df.tail()
# Out:
#      Coluna 1     Coluna 2   Coluna 3     Coluna 4  Coluna 5  Coluna 6  \
# 1112  Sudeste     Cristina 2011-03-19  Apartamento      87.5         2
# 1113  Sudeste       Simone 2011-03-20  Apartamento      74.5         2
# 1114    Norte  João Carlos 2011-03-21  Apartamento     192.0         4
# 1115    Leste       Simone 2011-03-27  Apartamento      42.0         1
# 1116    Oeste       Simone 2011-03-28  Apartamento     100.5         2
#
#       Coluna 7 Coluna 8  Coluna 8.1  Coluna 10
# 1112         0      Não      221500     3322.5
# 1113         2      Não      224400     3366.0
# 1114         4      Não      361000     5415.0
# 1115         1      Sim      167900     2518.5
# 1116         2      Sim      227600     3414.0

# %% [markdown]
# E) Escrever um programa para renomear o cabeçalho da tabela com os seguintes nome:

# %%
df.columns = ['filial','vendedor','data','tipo',
           'area(m)','dorms','garag.','piscina',
           'preco','comissao'
]
df.head()
# Out:
#      filial  vendedor       data         tipo  area(m)  dorms  garag. piscina  \
# 0    Centro    Simone 2005-10-08  Apartamento    102.5      2       2     Sim
# 1  Noroeste    Simone 2005-10-08  Apartamento    199.5      4       4     Não
# 2     Norte   Roberto 2005-10-12         Casa    145.5      2       2     Não
# 3   Sudeste    Simone 2005-10-14  Apartamento    153.5      3       2     Não
# 4  Noroeste  Cristina 2005-10-16  Apartamento     93.0      2       2     Sim
#
#     preco  comissao
# 0  235500    3532.5
# 1  377700    5665.5
# 2  232500    3487.5
# 3  289100    4336.5
# 4  235400    3531.0

# %% [markdown]
# G) Quais são os tipos de dados que temos no dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1117 entries, 0 to 1116
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filial    1117 non-null   object
#  1   vendedor  1117 non-null   object
#  2   data      1117 non-null   datetime64[ns]
#  3   tipo      1117 non-null   object
#  4   area(m)   1117 non-null   float64
#  5   dorms     1117 non-null   int64
#  6   garag.    1117 non-null   int64
#  7   piscina   1117 non-null   object
#  8   preco     1117 non-null   int64
#  9   comissao  1117 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(4)
# memory usage: 87.4+ KB

# %% [markdown]
# I) Calcule a soma, média, máxima, mínimo e contagem da coluna Preço

# %%
print('O valor total é: ',df['preco'].sum())

print('A média dos valores é: ',df['preco'].mean())

print('O maior valor é: ', df['preco'].max())

print('O menor valor é: ', df['preco'].count())
# Out:
# O valor total é:  295035000
# A média dos valores é:  264131.6025067144
# O maior valor é:  384300
# O menor valor é:  1117

# %%
df.describe()
# Out:
#            area(m)        dorms       garag.          preco     comissao
# count  1117.000000  1117.000000  1117.000000    1117.000000  1117.000000
# mean    125.965085     2.523724     1.646374  264131.602507  3961.974038
# std      53.290147     1.106603     1.233972   77249.578385  1158.743676
# min      25.000000     1.000000     0.000000  145100.000000  2176.500000
# 25%      82.000000     2.000000     1.000000  213500.000000  3202.500000
# 50%     127.000000     3.000000     2.000000  284300.000000  4264.500000
# 75%     169.500000     3.000000     3.000000  314700.000000  4720.500000
# max     245.000000     4.000000     4.000000  384300.000000  5764.500000

# %% [markdown]
# j) 8. Crie um programa para criar um dataframe para mostrar as vendas por
#  região, e salvar um arquivo em Excel para cada região.

# %%
# Filtrar um dataframe

df['filial']
# Out:
# 0         Centro
# 1       Noroeste
# 2          Norte
# 3        Sudeste
# 4       Noroeste
#           ...
# 1112     Sudeste
# 1113     Sudeste
# 1114       Norte
# 1115       Leste
# 1116       Oeste
# Name: filial, Length: 1117, dtype: object

# %%
# Traser somente uma região / condicional
df['filial'] == 'Norte'
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 1112    False
# 1113    False
# 1114     True
# 1115    False
# 1116    False
# Name: filial, Length: 1117, dtype: bool

# %%
df[df['filial'] == 'Norte']
# Out:
#      filial     vendedor       data         tipo  area(m)  dorms  garag.  \
# 2     Norte      Roberto 2005-10-12         Casa    145.5      2       2
# 10    Norte     Cristina 2005-10-30  Apartamento    136.5      3       1
# 19    Norte       Simone 2005-11-11  Apartamento    137.0      3       1
# 20    Norte      Roberto 2005-11-12         Casa    197.5      4       3
# 35    Norte  João Carlos 2005-12-17  Apartamento    190.5      4       4
# ...     ...          ...        ...          ...      ...    ...     ...
# 1097  Norte       Simone 2011-02-22         Casa     40.0      1       0
# 1098  Norte       Simone 2011-02-23         Casa    139.5      2       2
# 1106  Norte       Simone 2011-03-09  Apartamento    144.5      3       2
# 1110  Norte     Cristina 2011-03-17  Apartamento    102.5      2       0
# 1114  Norte  João Carlos 2011-03-21  Apartamento    192.0      4       4
#
#      piscina   preco  comissao
# 2        Não  232500    3487.5
# ...

# %%
df_norte = df[df['filial'] == 'Norte']

#Diretório de destino para salvar o arquivo

pasta_destino = 'C:\\Users\\FIC\\Documents\\Luiz Antonio Python\\003 - Arquivos\\imobiliaria resultado\\'

# Nome do Arquivo

nome_arquivo = 'Norte.xlsx'

# salvar/ Gerar um arquivo em exell

df_norte.to_excel(pasta_destino + nome_arquivo)

# %%
df_centro = df[df['filial'] == 'Centro']

#Diretório de destino para salvar o arquivo

pasta_destino = 'C:\\Users\\FIC\\Documents\\Luiz Antonio Python\\003 - Arquivos\\imobiliaria resultado\\'

# Nome do Arquivo

nome_arquivo = 'Centro.xlsx'

# salvar/ Gerar um arquivo em exell

df_centro.to_excel(pasta_destino + nome_arquivo)

# %%
df_noroeste = df[df['filial'] == 'Noroeste']

#Diretório de destino para salvar o arquivo

pasta_destino = 'C:\\Users\\FIC\\Documents\\Luiz Antonio Python\\003 - Arquivos\\imobiliaria resultado\\'

# Nome do Arquivo

nome_arquivo = 'Noroeste.xlsx'

# salvar/ Gerar um arquivo em exell

df_noroeste.to_excel(pasta_destino + nome_arquivo)

# %%
df_sudeste = df[df['filial'] == 'Sudeste']

#Diretório de destino para salvar o arquivo

pasta_destino = 'C:\\Users\\FIC\\Documents\\Luiz Antonio Python\\003 - Arquivos\\imobiliaria resultado\\'

# Nome do Arquivo

nome_arquivo = 'Sudeste.xlsx'

# salvar/ Gerar um arquivo em exell

df_sudeste.to_excel(pasta_destino + nome_arquivo)

# %%
df_oeste = df[df['filial'] == 'Oeste']

#Diretório de destino para salvar o arquivo

pasta_destino = 'C:\\Users\\FIC\\Documents\\Luiz Antonio Python\\003 - Arquivos\\imobiliaria resultado\\'

# Nome do Arquivo

nome_arquivo = 'Oeste.xlsx'

# salvar/ Gerar um arquivo em exell

df_oeste.to_excel(pasta_destino + nome_arquivo)

# %%
df_leste = df[df['filial'] == 'Leste']

#Diretório de destino para salvar o arquivo

pasta_destino = 'C:\\Users\\FIC\\Documents\\Luiz Antonio Python\\003 - Arquivos\\imobiliaria resultado\\'

# Nome do Arquivo

nome_arquivo = 'Leste.xlsx'

# salvar/ Gerar um arquivo em exell

df_leste.to_excel(pasta_destino + nome_arquivo)

# %%
df_sudoeste = df[df['filial'] == 'Sudoeste']

#Diretório de destino para salvar o arquivo

pasta_destino = 'C:\\Users\\FIC\\Documents\\Luiz Antonio Python\\003 - Arquivos\\imobiliaria resultado\\'

# Nome do Arquivo

nome_arquivo = 'Sudoeste.xlsx'

# salvar/ Gerar um arquivo em exell

df_sudoeste.to_excel(pasta_destino + nome_arquivo)

# %%
df_sul = df[df['filial'] == 'Sul']

#Diretório de destino para salvar o arquivo

pasta_destino = 'C:\\Users\\FIC\\Documents\\Luiz Antonio Python\\003 - Arquivos\\imobiliaria resultado\\'

# Nome do Arquivo

nome_arquivo = 'Sul.xlsx'

# salvar/ Gerar um arquivo em exell

df_sul.to_excel(pasta_destino + nome_arquivo)

# %%
df_nordeste = df[df['filial'] == 'Nordeste']

#Diretório de destino para salvar o arquivo

pasta_destino = 'C:\\Users\\FIC\\Documents\\Luiz Antonio Python\\003 - Arquivos\\imobiliaria resultado\\'

# Nome do Arquivo

nome_arquivo = 'Nordeste.xlsx'

# salvar/ Gerar um arquivo em exell

df_nordeste.to_excel(pasta_destino + nome_arquivo)

# %% [markdown]
# l) Gere um arquivo em Excel para representar as vendas efetuadas pela filial norte
# em 2010.

# %%
df.head()
# Out:
#      filial  vendedor       data         tipo  area(m)  dorms  garag. piscina  \
# 0    Centro    Simone 2005-10-08  Apartamento    102.5      2       2     Sim
# 1  Noroeste    Simone 2005-10-08  Apartamento    199.5      4       4     Não
# 2     Norte   Roberto 2005-10-12         Casa    145.5      2       2     Não
# 3   Sudeste    Simone 2005-10-14  Apartamento    153.5      3       2     Não
# 4  Noroeste  Cristina 2005-10-16  Apartamento     93.0      2       2     Sim
#
#     preco  comissao
# 0  235500    3532.5
# 1  377700    5665.5
# 2  232500    3487.5
# 3  289100    4336.5
# 4  235400    3531.0

# %%
df[df['data']=='2005-10-08']
# Out:
#      filial vendedor       data         tipo  area(m)  dorms  garag. piscina  \
# 0    Centro   Simone 2005-10-08  Apartamento    102.5      2       2     Sim
# 1  Noroeste   Simone 2005-10-08  Apartamento    199.5      4       4     Não
#
#     preco  comissao
# 0  235500    3532.5
# 1  377700    5665.5

# %%
# valores maior após  data 2005

df[df['data']>'2005-10-08']
# Out:
#         filial     vendedor       data         tipo  area(m)  dorms  garag.  \
# 2        Norte      Roberto 2005-10-12         Casa    145.5      2       2
# 3      Sudeste       Simone 2005-10-14  Apartamento    153.5      3       2
# 4     Noroeste     Cristina 2005-10-16  Apartamento     93.0      2       2
# 5        Oeste      Roberto 2005-10-17  Apartamento    124.0      3       2
# 6        Leste      Adriana 2005-10-18  Apartamento     98.5      2       1
# ...        ...          ...        ...          ...      ...    ...     ...
# 1112   Sudeste     Cristina 2011-03-19  Apartamento     87.5      2       0
# 1113   Sudeste       Simone 2011-03-20  Apartamento     74.5      2       2
# 1114     Norte  João Carlos 2011-03-21  Apartamento    192.0      4       4
# 1115     Leste       Simone 2011-03-27  Apartamento     42.0      1       1
# 1116     Oeste       Simone 2011-03-28  Apartamento    100.5      2       2
#
#      piscina   preco  comissao
# ...

# %%
df[(df['data']>'2005-10-14') & (df['data']<'2005-10-17')]
# Out:
#      filial  vendedor       data         tipo  area(m)  dorms  garag. piscina  \
# 4  Noroeste  Cristina 2005-10-16  Apartamento     93.0      2       2     Sim
#
#     preco  comissao
# 4  235400    3531.0

# %%
df[(df['data']>='2010-01-01') & (df['data']<='2010-12-31')]
# Out:
#         filial     vendedor       data         tipo  area(m)  dorms  garag.  \
# 852      Norte  João Carlos 2010-01-01  Apartamento     72.5      2       2
# 853     Centro      Roberto 2010-01-03  Apartamento     98.0      2       2
# 854      Norte      Ricardo 2010-01-06  Apartamento     33.5      1       0
# 855      Norte     Cristina 2010-01-07  Apartamento    133.0      3       2
# 856      Leste      Roberto 2010-01-08         Casa    170.0      3       3
# ...        ...          ...        ...          ...      ...    ...     ...
# 1059  Sudoeste      Adriana 2010-12-29         Casa    111.5      2       1
# 1060   Sudeste       Simone 2010-12-29  Apartamento    137.0      3       3
# 1061  Nordeste      Roberto 2010-12-31         Casa    192.0      3       2
# 1062       Sul       Simone 2010-12-31         Casa    156.0      3       1
# 1063  Noroeste  João Carlos 2010-12-31         Casa    183.5      4       3
#
#      piscina   preco  comissao
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1117 entries, 0 to 1116
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filial    1117 non-null   object
#  1   vendedor  1117 non-null   object
#  2   data      1117 non-null   datetime64[ns]
#  3   tipo      1117 non-null   object
#  4   area(m)   1117 non-null   float64
#  5   dorms     1117 non-null   int64
#  6   garag.    1117 non-null   int64
#  7   piscina   1117 non-null   object
#  8   preco     1117 non-null   int64
#  9   comissao  1117 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(4)
# memory usage: 87.4+ KB

# %%
dados = df[(df['data']>='2010-01-01') &
    (df['data']<='2010-12-31') & 
    (df['filial']=='Norte')]

# Nome do Arquivo

nome_arquivo = 'Norte_2010.xlsx'

#Salvar / Gerar um arquivo em excel

dados.to_excel(pasta_destino + nome_arquivo)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1117 entries, 0 to 1116
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filial    1117 non-null   object
#  1   vendedor  1117 non-null   object
#  2   data      1117 non-null   datetime64[ns]
#  3   tipo      1117 non-null   object
#  4   area(m)   1117 non-null   float64
#  5   dorms     1117 non-null   int64
#  6   garag.    1117 non-null   int64
#  7   piscina   1117 non-null   object
#  8   preco     1117 non-null   int64
#  9   comissao  1117 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(4)
# memory usage: 87.4+ KB

# %%
df.head()
# Out:
#      filial  vendedor       data         tipo  area(m)  dorms  garag. piscina  \
# 0    Centro    Simone 2005-10-08  Apartamento    102.5      2       2     Sim
# 1  Noroeste    Simone 2005-10-08  Apartamento    199.5      4       4     Não
# 2     Norte   Roberto 2005-10-12         Casa    145.5      2       2     Não
# 3   Sudeste    Simone 2005-10-14  Apartamento    153.5      3       2     Não
# 4  Noroeste  Cristina 2005-10-16  Apartamento     93.0      2       2     Sim
#
#     preco  comissao
# 0  235500    3532.5
# 1  377700    5665.5
# 2  232500    3487.5
# 3  289100    4336.5
# 4  235400    3531.0

# %%
df[df['tipo']== 'Casa']
# Out:
#         filial     vendedor       data  tipo  area(m)  dorms  garag. piscina  \
# 2        Norte      Roberto 2005-10-12  Casa    145.5      2       2     Não
# 7     Sudoeste      Roberto 2005-10-19  Casa    109.0      2       2     Não
# 8     Sudoeste  João Carlos 2005-10-21  Casa    137.5      3       1     Não
# 12      Centro      Adriana 2005-11-01  Casa    191.0      3       3     Sim
# 16         Sul       Simone 2005-11-04  Casa    122.0      2       2     Não
# ...        ...          ...        ...   ...      ...    ...     ...     ...
# 1103     Leste  João Carlos 2011-03-03  Casa    168.0      3       1     Não
# 1105     Oeste      Roberto 2011-03-06  Casa    125.5      3       3     Sim
# 1107       Sul  João Carlos 2011-03-10  Casa     81.0      1       0     Não
# 1108   Sudeste     Cristina 2011-03-12  Casa    185.5      3       1     Não
# 1109  Nordeste      Ricardo 2011-03-15  Casa    135.5      2       2     Não
#
#        preco  comissao
# ...

# %%
df[(df['tipo']== 'Casa') & (df['garag.']==0)]
# Out:
#         filial     vendedor       data  tipo  area(m)  dorms  garag. piscina  \
# 30    Nordeste  João Carlos 2005-12-07  Casa    101.5      2       0     Sim
# 51    Sudoeste      Roberto 2006-01-09  Casa     89.0      1       0     Sim
# 54       Leste      Adriana 2006-01-13  Casa    109.5      2       0     Sim
# 61    Noroeste      Adriana 2006-01-20  Casa     68.5      1       0     Sim
# 73     Sudeste      Roberto 2006-02-13  Casa    142.0      2       0     Sim
# ...        ...          ...        ...   ...      ...    ...     ...     ...
# 1078     Oeste     Cristina 2011-01-29  Casa     59.5      1       0     Sim
# 1082  Nordeste     Cristina 2011-01-31  Casa     74.5      1       0     Não
# 1091  Sudoeste  João Carlos 2011-02-09  Casa     71.5      1       0     Não
# 1097     Norte       Simone 2011-02-22  Casa     40.0      1       0     Não
# 1107       Sul  João Carlos 2011-03-10  Casa     81.0      1       0     Não
#
#        preco  comissao
# ...

# %%
dados = df[(df['tipo']=='Casa') & (df['garag.']==0) & (df['filial']=='Sudeste') &(df['data']>='2010-01-01') & (df['data']<= '2010-12-31')]

# Nome do Arquivo
nome_arquivo = 'sudeste_2010_casa_semGarag.xlsx'

#Salvar / Gerar um arquivo em excel

dados.to_excel(pasta_destino + nome_arquivo)

# %% [markdown]
# m) Gere um arquivo em Excel para representar as vendas efetuadas pela filial
# Sudeste em 2010. Sendo que no relatório deve conter apenas vendas de casas
# sem garagem.

# %%
dados = df[(df['data']>='2010-01-01') &
    (df['data']<='2010-12-31') & 
    (df['filial']=='Sudeste')]

# Nome do Arquivo

nome_arquivo = 'Sudeste_2010.xlsx'

#Salvar / Gerar um arquivo em excel

dados.to_excel(pasta_destino + nome_arquivo)

# %% [markdown]
# n) Qual o valor máximo de comissão que a imobiliária numa venda?

# %%
df['comissao'].max()
# Out:
# 5764.5

# %%
# Retornart registro referente ao maior valor
df[df['comissao'] == df['comissao'].max()]
# Out:
#     filial vendedor       data         tipo  area(m)  dorms  garag. piscina  \
# 848    Sul  Adriana 2009-12-27  Apartamento    188.5      4       4     Sim
#
#       preco  comissao
# 848  384300    5764.5

# %% [markdown]
# o) Quantas casas de 2 ou 3 dormitórios foram vendidas pelo Ricardo antes de 2011.

# %%
df.head()

# coluna vendedor
# Out:
#      filial  vendedor       data         tipo  area(m)  dorms  garag. piscina  \
# 0    Centro    Simone 2005-10-08  Apartamento    102.5      2       2     Sim
# 1  Noroeste    Simone 2005-10-08  Apartamento    199.5      4       4     Não
# 2     Norte   Roberto 2005-10-12         Casa    145.5      2       2     Não
# 3   Sudeste    Simone 2005-10-14  Apartamento    153.5      3       2     Não
# 4  Noroeste  Cristina 2005-10-16  Apartamento     93.0      2       2     Sim
#
#     preco  comissao
# 0  235500    3532.5
# 1  377700    5665.5
# 2  232500    3487.5
# 3  289100    4336.5
# 4  235400    3531.0

# %%
df[df['vendedor']== 'Ricardo']
# Out:
#         filial vendedor       data         tipo  area(m)  dorms  garag.  \
# 18    Nordeste  Ricardo 2005-11-06         Casa     66.5      1       1
# 22    Nordeste  Ricardo 2005-11-18         Casa     91.5      1       1
# 31    Sudoeste  Ricardo 2005-12-08  Apartamento     86.5      2       1
# 33    Sudoeste  Ricardo 2005-12-15  Apartamento     98.0      2       0
# 52      Centro  Ricardo 2006-01-09         Casa    218.5      4       3
# ...        ...      ...        ...          ...      ...    ...     ...
# 1081     Oeste  Ricardo 2011-01-30  Apartamento    194.5      4       4
# 1088     Oeste  Ricardo 2011-02-07  Apartamento     29.0      1       1
# 1093    Centro  Ricardo 2011-02-15  Apartamento    182.5      4       2
# 1094  Noroeste  Ricardo 2011-02-19  Apartamento    163.5      4       4
# 1109  Nordeste  Ricardo 2011-03-15         Casa    135.5      2       2
#
#      piscina   preco  comissao
# 18       Não  160500    2407.5
# 22       Não  161100    2416.5
# ...

# %%
 
# menor que 01-01-2011
# Pega data de referencia

df[(df['vendedor']=='Ricardo') & 
   (df['data']<'2011-01-01') &
   (df['tipo']=='Casa') &

    ((df['dorms']==2) |
    (df['dorms']==3))
    
    ]
# Out:
#         filial vendedor       data  tipo  area(m)  dorms  garag. piscina  \
# 82       Norte  Ricardo 2006-02-28  Casa    153.0      3       3     Sim
# 100      Oeste  Ricardo 2006-04-08  Casa    146.5      3       3     Sim
# 156     Centro  Ricardo 2006-07-12  Casa    105.5      2       1     Não
# 171      Norte  Ricardo 2006-07-27  Casa    104.0      2       1     Não
# 184      Leste  Ricardo 2006-08-30  Casa    144.5      3       3     Não
# 200   Noroeste  Ricardo 2006-09-25  Casa    148.5      3       3     Não
# 206        Sul  Ricardo 2006-10-02  Casa    185.0      3       2     Não
# 214      Leste  Ricardo 2006-10-16  Casa    149.5      3       3     Não
# 251   Noroeste  Ricardo 2006-12-13  Casa    109.5      2       2     Sim
# 263   Noroeste  Ricardo 2006-12-29  Casa    101.5      2       0     Não
# 278   Nordeste  Ricardo 2007-01-28  Casa    124.5      2       0     Não
# 291      Norte  Ricardo 2007-02-27  Casa    137.0      2       2     Não
# ...
